737, 0.431034482758624, -0.4022988505747093, -0.028735632183902737, 0.2873563218390747, 0.25862068965517204, 0.028735632183902737, -0.20114942528735466, -0.37356321839080664, -0.6034482758620641, -0.5747126436781613, -0.5747126436781613, -0.4885057471264413, -0.37356321839080664, -0.7847701149425509, -1.1339080459770183, -1.0175287356321878, -1.3666666666666791, -1.1339080459770183, -0.7847701149425509, -0.7847701149425509, -1.1339080459770183, -0.7847701149425509, -0.6683908045977205, -2.297701149425298, -1.3666666666666791, -0.7847701149425509, -0.6683908045977205, -0.9011494252873574, -1.3666666666666791, -1.4830459770115094, -1.1339080459770183, -1.5994252873563395, -1.3666666666666791, -1.4830459770115094, -1.3666666666666791, -1.0175287356321878, -1.0175287356321878, -1.3666666666666791, -1.2502873563218486, -0.6683908045977205, -1.4830459770115094, -0.9011494252873574, -1.3666666666666791, -0.7847701149425509, -0.9011494252873574, -1.8321839080460003, -1.0175287356321878, -1.3666666666666791, -1.3666666666666791, -1.0175287356321878, -1.1339080459770183, -1.0175287356321878, -0.9011494252873574, -0.9011494252873574, -1.36 ...
# 2049

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd



max_length = max(len(Frset[0]), len(Frset[1]), len(Frset[2]), len(Frset[3]), len(Frset[4]), len(Frset[5]))
Frset1 = []

for data in Frset:
    data += [np.nan] * (max_length - len(data))
    Frset1.append(data)



# Combine data into a DataFrame
df = pd.DataFrame({
    '120': Frset1[0],
    '100': Frset1[1],
    '80': Frset1[2],
    '60': Frset1[3],
    '40': Frset1[4],
    '20': Frset1[5]
})

# Melt the DataFrame to long format
df_melted = pd.melt(df, var_name='Group', value_name='Value')

blue_palette = sns.color_palette("Blues", n_colors=6)



# Create grouped violin plot
plt.figure(figsize=(6, 4))
sns.violinplot(x='Group', y='Value', data=df_melted, inner='quartile',palette=blue_palette, width=0.8)
plt.xlabel('Set Flow Rate (ul/min)')
plt.ylabel('Flow Rate Percentage Error (%)')
plt.savefig('FlowControl3.png', bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# C:\Users\bdigg\AppData\Local\Temp\ipykernel_24776\2029663065.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Group', y='Value', data=df_melted, inner='quartile',palette=blue_palette, width=0.8)

# %%
import pandas as pd
from pandas import DataFrame as df
import matplotlib.pyplot as plt
sheet1 = pd.read_excel(r"./Logs/160424-Switching.xlsx", 'Sheet1')["Eq Time"]
print(sheet1)
#Switching from 120
Frval = [50,30,70]
Eqtime = [[],[],[]]
start,end = 0,7
for k, Fr in enumerate(Frval):
    Eqtime[k].append(np.array(sheet1[start+1:start+8]))
    Eqtime[k].append(np.array(sheet1[start+9:start+16]))
    Eqtime[k].append(np.array(sheet1[start+17:start+24]))
    Eqtime[k].append(np.array(sheet1[start+25:start+30]))
    start = start + 30
print(Eqtime[1])
print(Eqtime[2])
print(Eqtime[0])
# Out:
# 0     12.639452
# 1     19.453556
# 2     15.596896
# 3     15.022110
# 4      9.751437
#         ...
# 91    11.825019
# 92     9.265724
# 93    11.199468
# 94     8.056717
# 95     6.406356
# Name: Eq Time, Length: 96, dtype: float64
# [array([16.81225729, 11.010674  , 45.03531885, 12.67062426, 35.94133615,
#         9.36601996, 27.32236004]), array([29.41225958,  9.31859398, 13.32841039, 10.97431254, 45.36382389,
#        12.49370074,  9.71640396]), array([32.80199504, 11.03128409, 13.4664104 , 10.58674741, 18.99205232,
#         9.69827366, 19.41702676]), array([15.35441303, 12.47594166, 21.96863437, 12.51295376, 21.4589467 ])]
# [array([19.16429377, 14.66452265, 19.39695287, 10.7955811 , 17.81744194,
#        11.05679727,  8.26597118]), array([ 8.75656772,  9.80031443, 14.29162502,  6.81427693, 11.49763274,
#        10.17659974, 12.95473385]), array([11.92068672,  8.7203393 , 10.29727721,  8.28719378, 40.0959549 ,
#         9.75283313, 10.56903815]), array([10.60745811, 11.9564116 , 12.22531652, 12.87909341, 14.54336119])]
# [array([19.4535563 , 15.59689569, 15.02210951,  9.75143719, 11.08563638,
#        10.88839316, 17.41162944]), array([11.57954693, 11.85841751, 10.80650949, 10.90819073, 12.58364224,
#        12.18889046, 15.25655293]), array([19.09450865, 22.31742501, 45.45115924,  8.49189782, 14.00862741,
#         7.93414521, 17.93478179]), array([25.54635286,  9.69411826, 18.2607336 ,  9.22390938, 16.10369873])]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

swchans = ["4 Channel Switch","3 Channel Switch","2 Channel Switch","1 Channel Switch"]

for i, title in enumerate(swchans):
    # Combine data into a DataFrame

    print(len(Eqtime[2][i]),len(Eqtime[0][i]),len(Eqtime[1][i]))
    df = pd.DataFrame({
        '120-70': Eqtime[2][i],
        '120-50': Eqtime[0][i],
        '120-30': Eqtime[1][i],
    })

    # Melt the DataFrame to long format
    df_melted = pd.melt(df, var_name='Group', value_name='Value')

    blue_palette = sns.color_palette("Blues", n_colors=6)



    # Create grouped violin plot
    plt.figure(figsize=(6, 8))
    plt.title(title)
    #sns.violinplot(x='Group', y='Value', data=df_melted, inner='quartile',palette=blue_palette, width=0.8)
    sns.boxplot(x='Group', y='Value', data=df_melted,palette=blue_palette, width=0.8)
    plt.xlabel('Set Flow Rate (ul/min)')
    plt.ylim(0,50)
    plt.ylabel('Switching Time (s)')
    plt.savefig('SwitchingTime.png', bbox_inches='tight', dpi=1000)
    plt.show()
# Out:
# 7 7 7
# C:\Users\bdigg\AppData\Local\Temp\ipykernel_24776\2113099168.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Value', data=df_melted,palette=blue_palette, width=0.8)
# C:\Users\bdigg\AppData\Local\Temp\ipykernel_24776\2113099168.py:28: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.boxplot(x='Group', y='Value', data=df_melted,palette=blue_palette, width=0.8)
# 7 7 7
# C:\Users\bdigg\AppData\Local\Temp\ipykernel_24776\2113099168.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Value', data=df_melted,palette=blue_palette, width=0.8)
# C:\Users\bdigg\AppData\Local\Temp\ipykernel_24776\2113099168.py:28: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.boxplot(x='Group', y='Value', data=df_melted,palette=blue_palette, width=0.8)
# 7 7 7
# C:\Users\bdigg\AppData\Local\Temp\ipykernel_24776\2113099168.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Value', data=df_melted,palette=blue_palette, width=0.8)
# C:\Users\bdigg\AppData\Local\Temp\ipykernel_24776\2113099168.py:28: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.boxplot(x='Group', y='Value', data=df_melted,palette=blue_palette, width=0.8)
# 5 5 5
# C:\Users\bdigg\AppData\Local\Temp\ipykernel_24776\2113099168.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Value', data=df_melted,palette=blue_palette, width=0.8)
# C:\Users\bdigg\AppData\Local\Temp\ipykernel_24776\2113099168.py:28: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.boxplot(x='Group', y='Value', data=df_melted,palette=blue_palette, width=0.8)
